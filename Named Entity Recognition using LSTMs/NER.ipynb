# %% [markdown]
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with Keras</h2>

# %% [markdown]
# ### 1. Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.5.0
# GPU detected: []

# %% [markdown]
# ### 2. Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### 3. Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### 4. Define Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'Society': 1,
#  'F': 2,
#  'City': 3,
#  'commandeered': 4,
#  '1826': 5,
#  'sped': 6,
#  'Sukhoi': 7,
#  'reconnaissance': 8,
#  'vaccines': 9,
#  'horse': 10,
#  'Joey': 11,
#  'fees': 12,
#  'earmarks': 13,
#  'Haridy': 14,
#  'Prices': 15,
#  'dams': 16,
#  'Forty-nine': 17,
#  'Bagram': 18,
#  'Approval': 19,
#  'bounce': 20,
#  'attracted': 21,
#  'CHISSANO': 22,
#  '9.5': 23,
#  'consulting': 24,
#  'memorials': 25,
#  'Inc': 26,
#  'substantiate': 27,
#  'assuring': 28,
#  'bridged': 29,
#  'jury': 30,
#  're-establishing': 31,
#  'Someone': 32,
#  'administer': 33,
#  'ownership': 34,
#  'non-party': 35,
#  'Burma-Thailand': 36,
#  'calling': 37,
#  'frequently': 38,
#  'make-believe': 39,
#  'Shkin': 40,
#  'notify': 41,
#  'Saakashvili': 42,
#  'Sandstorms': 43,
#  'Budgetary': 44,
#  'curbing': 45,
#  'orders': 46,
#  'Valdivia': 47,
#  'manifestations': 48,
#  'Yuriy': 49,
#  'writings': 50,
#  'fragmentary': 51,
#  'susceptible': 52,
#  'pre-conflict': 53,
#  'Loud': 54,
#  'steadfastly': 55,
#  'non-Muslim': 56,
#  'flowering': 57,
#  'Ford': 58,
#  'used': 59,
#  'wheels': 60,
#  "L'Aquilla": 61,
#  'Göteborg': 62,
#  'Prayer': 63,
#  'good-naturedly': 64,
#  'Dhekelia': 65,
#  'murder': 66,
#  'Late': 67,
#  'motorbike': 68,
#  'Villepin': 69,
#  'benefits': 70,
#  'pressured': 71,
#  'fourth-largest': 72,
#  'al-Faraa': 73,
#  'pests': 74,
#  '8,000': 75,
#  'Despite': 76,
#  'habitat': 77,
#  'Mercantile': 78,
#  'dwindling': 79,
#  'Migrants': 80,
#  'government-sponsored': 81,
#  'Non-Sawang': 82,
#  'resales': 83,
#  'globally': 84,
#  'one-stop': 85,
#  'helps': 86,
#  'Tong': 87,
#  'Elevators': 88,
#  'cares': 89,
#  'Guiana': 90,
#  'artistic': 91,
#  'Strategies': 92,
#  'Moscow-leaning': 93,
#  'Dabous': 94,
#  'communiqué': 95,
#  'morale-boosting': 96,
#  '1822': 97,
#  '351-7': 98,
#  'Ko': 99,
#  'Nino': 100,
#  'GEO': 101,
#  'Newspaper': 102,
#  'stoked': 103,
#  'retroactively': 104,
#  'Marinin': 105,
#  'Palma': 106,
#  'soy': 107,
#  'harden': 108,
#  'Allegations': 109,
#  'ejected': 110,
#  'Gush': 111,
#  'Bordeaux': 112,
#  'twins': 113,
#  'implicate': 114,
#  'voicing': 115,
#  'contaminated': 116,
#  'publisher': 117,
#  'MPRP': 118,
#  'handovers': 119,
#  'holders': 120,
#  'US-India': 121,
#  'German-owned': 122,
#  'member-states': 123,
#  'concludes': 124,
#  'Governor': 125,
#  'Sochi': 126,
#  'Hosada': 127,
#  'Gamsakhurdia': 128,
#  'mosquitoes': 129,
#  'KHAAN': 130,
#  'House-to-house': 131,
#  'passersby': 132,
#  'pinna': 133,
#  'telling': 134,
#  'Jib': 135,
#  'unlucky': 136,
#  'plaintiff': 137,
#  '2,40,000': 138,
#  'task': 139,
#  'head-on': 140,
#  'struggles': 141,
#  'boasting': 142,
#  'difference': 143,
#  'Manufacturing': 144,
#  'unauthorized': 145,
#  'U.S.-India': 146,
#  'Annie': 147,
#  'judgmental': 148,
#  'Foxes': 149,
#  'fertilized': 150,
#  'Ramadan': 151,
#  'Child': 152,
#  'mummy': 153,
#  'criminalizing': 154,
#  'trans-Atlantic': 155,
#  'Coordinating': 156,
#  'Patriot': 157,
#  'Boroujerdi': 158,
#  'E.U.': 159,
#  'shuffle': 160,
#  'deprivation': 161,
#  'previous': 162,
#  'Claire': 163,
#  'Arbitration': 164,
#  'Chulanont': 165,
#  'capitalize': 166,
#  'Expatriates': 167,
#  'supplemented': 168,
#  'Arab': 169,
#  'underreporting': 170,
#  'Chrysostomos': 171,
#  'subdue': 172,
#  'MIddle': 173,
#  'EST': 174,
#  '22.4': 175,
#  'uncontained': 176,
#  'inviting': 177,
#  'wreaths': 178,
#  '442': 179,
#  'caffeine': 180,
#  'cash-strapped': 181,
#  'hierarchy': 182,
#  'bleeding': 183,
#  'miscalculated': 184,
#  'Akhbar': 185,
#  'Houghton': 186,
#  '21-year-old': 187,
#  'Dogg': 188,
#  'contest': 189,
#  'taxes': 190,
#  'asks': 191,
#  'vampire': 192,
#  'methodology': 193,
#  'Kaliningrad': 194,
#  'freezes': 195,
#  'burgeoning': 196,
#  'Banja': 197,
#  'NIST': 198,
#  '6,10,000': 199,
#  'exception': 200,
#  'million-dollar': 201,
#  'Bangalore': 202,
#  'Anheuser-Busch': 203,
#  'ship-to-ship': 204,
#  'Malays': 205,
#  'slumber': 206,
#  'ecologic': 207,
#  'Echeverria': 208,
#  'Vlore': 209,
#  'farce': 210,
#  'self-governing': 211,
#  'staff': 212,
#  '28,000': 213,
#  'firing': 214,
#  'Rolls': 215,
#  'characteristic': 216,
#  'heat-trapping': 217,
#  'Taro': 218,
#  'uncover': 219,
#  'wide': 220,
#  'caw': 221,
#  'fraction': 222,
#  'blasting': 223,
#  'super-combined': 224,
#  'reconciliation': 225,
#  'Kars-Akhalkalaki': 226,
#  '1697': 227,
#  'Muslim': 228,
#  'barked': 229,
#  '1941': 230,
#  'Blanchett': 231,
#  'Qar': 232,
#  'monsoon': 233,
#  'Adilgerei': 234,
#  'project': 235,
#  'wicket': 236,
#  '1,170': 237,
#  'Pohamba': 238,
#  'seeded': 239,
#  'Heihe': 240,
#  'Gimelstob': 241,
#  'Noire': 242,
#  'Buttiglione': 243,
#  'Letten': 244,
#  'greenback': 245,
#  'testifying': 246,
#  'Lithium': 247,
#  'plants': 248,
#  'K.': 249,
#  'grand': 250,
#  'Telegraph': 251,
#  'Cardinal': 252,
#  'Renen': 253,
#  'Abdel-Al': 254,
#  '4,480': 255,
#  'mine': 256,
#  'Several': 257,
#  'eyes': 258,
#  'replacement': 259,
#  'reviving': 260,
#  'mission': 261,
#  'anti-communist': 262,
#  'Back': 263,
#  'Da': 264,
#  'Woodrow': 265,
#  'Alasay': 266,
#  'Koichi': 267,
#  'Transport': 268,
#  'militant-appointed': 269,
#  'Serhiy': 270,
#  'anti-inflationary': 271,
#  'underway': 272,
#  'exported': 273,
#  'command': 274,
#  'Sander': 275,
#  'SWAPO': 276,
#  'Semlow': 277,
#  'arap': 278,
#  'Swaziland': 279,
#  'AU-sponsored': 280,
#  'Armenia': 281,
#  'Shidiac': 282,
#  'wallet': 283,
#  'dikes': 284,
#  'GAO': 285,
#  'Ingmar': 286,
#  'designing': 287,
#  'performs': 288,
#  '101': 289,
#  'somewhat': 290,
#  'Jamaican-born': 291,
#  'headlines': 292,
#  'dismissed': 293,
#  'Blackwater': 294,
#  '17,765': 295,
#  'abetting': 296,
#  'thanking': 297,
#  'bullet': 298,
#  're-sales': 299,
#  'Oliveira': 300,
#  'Pemex': 301,
#  'done': 302,
#  'I': 303,
#  'complained': 304,
#  'identifications': 305,
#  'rumors': 306,
#  'Catu': 307,
#  'Pro-Russian': 308,
#  'mother-to-child': 309,
#  'shadows': 310,
#  '-': 311,
#  '12-year': 312,
#  'McDaniel': 313,
#  'gnawed': 314,
#  'Numaniya': 315,
#  'deciphering': 316,
#  'Général': 317,
#  'assailant': 318,
#  'Tassos': 319,
#  'checkpost': 320,
#  'shoe-bombing': 321,
#  'zookeepers': 322,
#  'Baki': 323,
#  'stand-by': 324,
#  '32-year-old': 325,
#  'tear-gas': 326,
#  'Per': 327,
#  'colored': 328,
#  'residing': 329,
#  'gadgets': 330,
#  'Neskovic': 331,
#  'fourth-quarter': 332,
#  'LARK': 333,
#  '1650': 334,
#  'closed': 335,
#  '1997': 336,
#  'lifetime': 337,
#  'Registration': 338,
#  'confiscate': 339,
#  '38.5': 340,
#  'al-Zahar': 341,
#  'cornerstone': 342,
#  'Both': 343,
#  'eat': 344,
#  'Cary': 345,
#  '0.068171296': 346,
#  'Ruz': 347,
#  'overaggressive': 348,
#  '600-meter-long': 349,
#  'hepatitis': 350,
#  'Literature': 351,
#  'Shawn': 352,
#  'conducted': 353,
#  'tendering': 354,
#  '40-year-old': 355,
#  'Tzipi': 356,
#  'Mahmanparast': 357,
#  '800': 358,
#  'Utiashvili': 359,
#  'Etman': 360,
#  'IEDs': 361,
#  'Djibouti-Yemen': 362,
#  'prefer': 363,
#  'record-setting': 364,
#  'farmland': 365,
#  'Smolensk': 366,
#  'Sher': 367,
#  '7th': 368,
#  'Sufi': 369,
#  'straight-sets': 370,
#  'strengthens': 371,
#  'bylaw': 372,
#  'Kidnappings': 373,
#  'cut-off': 374,
#  'Vives': 375,
#  'robustly': 376,
#  'Slovakia': 377,
#  'main': 378,
#  'Kapisa': 379,
#  'citizens': 380,
#  'distinctive': 381,
#  'Masked': 382,
#  'IRIN': 383,
#  'Allen': 384,
#  'alternates': 385,
#  'circulating': 386,
#  '1,250': 387,
#  'undrafted': 388,
#  'Badaun': 389,
#  'Sardenberg': 390,
#  'punished': 391,
#  'constructively': 392,
#  'compatible': 393,
#  'whereby': 394,
#  'Stewart': 395,
#  'rubble': 396,
#  'nullified': 397,
#  'Gonzalez': 398,
#  '1814': 399,
#  'Seventeen-year-old': 400,
#  'Macedonia': 401,
#  'faiths': 402,
#  'scenic': 403,
#  'Gwyneth': 404,
#  'Haitian': 405,
#  'infrastructure': 406,
#  'Danielle': 407,
#  'balloons': 408,
#  'aid': 409,
#  'waved': 410,
#  'Presidents': 411,
#  'Juliana': 412,
#  'Younus': 413,
#  'Democrat-controlled': 414,
#  'Malam': 415,
#  'Logarda': 416,
#  'Lankans': 417,
#  'Wikipedia': 418,
#  'looters': 419,
#  'kidnapping': 420,
#  'select': 421,
#  'Ethiopian-backed': 422,
#  'Silva': 423,
#  'smoker': 424,
#  'Thick': 425,
#  '0.35': 426,
#  'Earth': 427,
#  'Actors': 428,
#  'flame-throwers': 429,
#  'warranted': 430,
#  're-election': 431,
#  'barren': 432,
#  'U.N.-protected': 433,
#  '1648': 434,
#  'Nureddin': 435,
#  'historian': 436,
#  'Proved': 437,
#  'NCRI': 438,
#  'align': 439,
#  'herd': 440,
#  '1004': 441,
#  'tissue': 442,
#  'solemnly': 443,
#  'fuel-making': 444,
#  'Co.': 445,
#  'thereby': 446,
#  'simplify': 447,
#  'A380': 448,
#  'grebe': 449,
#  'sisters': 450,
#  'elaborating': 451,
#  'Since': 452,
#  '03-May': 453,
#  'gymnast': 454,
#  'U.S.-funded': 455,
#  'Macy': 456,
#  'Likely': 457,
#  'US-Colombia': 458,
#  'Almagro': 459,
#  'Khayam': 460,
#  'eurozone': 461,
#  'state-monitored': 462,
#  'front-page': 463,
#  'hurt': 464,
#  'ending': 465,
#  'thyself': 466,
#  'SK': 467,
#  'Chanderpaul': 468,
#  'outing': 469,
#  'Surkhanpha': 470,
#  'fallen': 471,
#  'zealous': 472,
#  'oft': 473,
#  'one-sixth': 474,
#  'insulting': 475,
#  'reliable': 476,
#  'equalizer': 477,
#  'Changqi': 478,
#  'round': 479,
#  'radios': 480,
#  'cynics': 481,
#  'begun': 482,
#  'stakes': 483,
#  'Adamkus': 484,
#  'Bahadur': 485,
#  'Shiekh': 486,
#  'Oregon': 487,
#  'sold-out': 488,
#  'Ran': 489,
#  'Baqer': 490,
#  'Sharq': 491,
#  'late-morning': 492,
#  'Creator': 493,
#  '7,50,000': 494,
#  'Maddalena': 495,
#  'stakeholder': 496,
#  'reverence': 497,
#  'Pope2You': 498,
#  'Gollnisch': 499,
#  'wrapping': 500,
#  'Gojko': 501,
#  'Latvian': 502,
#  'Haniyeh': 503,
#  'Pittsburgh': 504,
#  'Village': 505,
#  'horrified': 506,
#  'facets': 507,
#  'Bam': 508,
#  'focused': 509,
#  'Gurirab': 510,
#  'welfare-dependent': 511,
#  'Andreas': 512,
#  'mobs': 513,
#  'ambient': 514,
#  'Sisli': 515,
#  'Pudong': 516,
#  'brawl': 517,
#  'annul': 518,
#  'festive': 519,
#  'balanced': 520,
#  'Ice': 521,
#  'preferred': 522,
#  'lukewarm': 523,
#  'Abdolvahed': 524,
#  'Atoms': 525,
#  'waistcoat': 526,
#  'Coretta': 527,
#  'flow': 528,
#  '80-kilometer-long': 529,
#  '64th': 530,
#  'automobiles': 531,
#  'Melissa': 532,
#  'Ellsworth': 533,
#  'Dechy': 534,
#  'Nazarbayev': 535,
#  'Rights': 536,
#  'Michoacan': 537,
#  'Campaigning': 538,
#  'reclassify': 539,
#  'self-ruled': 540,
#  'tripartite': 541,
#  'Rafsanjani': 542,
#  'demented': 543,
#  'salvaged': 544,
#  'Noor': 545,
#  'Yemen': 546,
#  'catering': 547,
#  'Haidar': 548,
#  'Ishaq': 549,
#  'constrained': 550,
#  'block-to-block': 551,
#  'infiltrations': 552,
#  'league': 553,
#  'ultra-nationalist': 554,
#  'Anglo-Leasing': 555,
#  'Cornwall': 556,
#  'Russian-built': 557,
#  '2,30,000': 558,
#  'mid-1970s': 559,
#  'Mint': 560,
#  'Georg': 561,
#  '124': 562,
#  'faithful': 563,
#  'Administrative': 564,
#  'Judges': 565,
#  'Eighteen': 566,
#  'use': 567,
#  'Edouard': 568,
#  'Pettigrew': 569,
#  'teen': 570,
#  'Seyoum': 571,
#  'extort': 572,
#  'Phukphasuk': 573,
#  'Xinhua': 574,
#  'Bolivian': 575,
#  'Desert': 576,
#  'offshoot': 577,
#  'shortfalls': 578,
#  'researching': 579,
#  'Manifesto': 580,
#  '722': 581,
#  'unreleased': 582,
#  'mourning': 583,
#  'commercially-available': 584,
#  'stages': 585,
#  'MILF': 586,
#  'H.I.V': 587,
#  'mixture': 588,
#  'Smith': 589,
#  'Murr': 590,
#  'Fadhila': 591,
#  'denuded': 592,
#  'Disney': 593,
#  'Osaka': 594,
#  'Krzanich': 595,
#  'Nineveh': 596,
#  'fascinate': 597,
#  'Marcelo': 598,
#  'Pedraz': 599,
#  'Discussions': 600,
#  'mercy': 601,
#  'headcount-control': 602,
#  'Surrounded': 603,
#  'Nazari': 604,
#  'refineries': 605,
#  'lightening': 606,
#  'Embraer': 607,
#  'represented': 608,
#  '\x92s': 609,
#  'accomplice': 610,
#  'S.P.': 611,
#  'Actor': 612,
#  'Hamshahri': 613,
#  'sufferer': 614,
#  'Sustiva': 615,
#  'Senegal-based': 616,
#  'AIDS-related': 617,
#  'Spokesman': 618,
#  '20s': 619,
#  'Baker': 620,
#  'barricade': 621,
#  'Service': 622,
#  'diver': 623,
#  'Physically': 624,
#  'overheating': 625,
#  'Beltran': 626,
#  'related': 627,
#  'ethnic-Albanian': 628,
#  'assignments': 629,
#  'greenhouse': 630,
#  'al-Arabiya': 631,
#  'Yemen-based': 632,
#  'comment': 633,
#  'Key': 634,
#  'eruptions': 635,
#  'Doetinchem': 636,
#  'rigid': 637,
#  'Glasgow': 638,
#  'electronically': 639,
#  'Tulane': 640,
#  'Sheng': 641,
#  'wraps': 642,
#  'inhabit': 643,
#  'openly': 644,
#  'huntsmen': 645,
#  'Paper': 646,
#  'recompense': 647,
#  'insider': 648,
#  'Hydropower': 649,
#  'solar': 650,
#  'brewer': 651,
#  'Responsibility': 652,
#  'oceanographic': 653,
#  'Volodymyr': 654,
#  'Megan': 655,
#  'salaries': 656,
#  'shoot-out': 657,
#  'ASEAN': 658,
#  'Sfeir': 659,
#  'receives': 660,
#  '149': 661,
#  'independently': 662,
#  '28': 663,
#  '3,400-meter-high': 664,
#  'day': 665,
#  'uprisings': 666,
#  'informants': 667,
#  '53rd': 668,
#  'best': 669,
#  'Vatican': 670,
#  'Mwakalyelye': 671,
#  'thousands': 672,
#  'Shannon': 673,
#  'trailing': 674,
#  'readmitted': 675,
#  'ABHISIT': 676,
#  'Foods': 677,
#  'clipped': 678,
#  '3,000-meters': 679,
#  'rain-interrupted': 680,
#  'slim': 681,
#  'extinct': 682,
#  'spies': 683,
#  'expect': 684,
#  'Chora': 685,
#  '1,70,000': 686,
#  'archbishop': 687,
#  'trampling': 688,
#  'bin-Laden': 689,
#  '1892': 690,
#  'in': 691,
#  'avocados': 692,
#  'grounds': 693,
#  'Tandja': 694,
#  'Kaibyshev': 695,
#  'member': 696,
#  '10-man': 697,
#  'reconsider': 698,
#  'mobster': 699,
#  'yacht': 700,
#  'ordnance': 701,
#  '1,28,000': 702,
#  'Serge': 703,
#  'manufacturing': 704,
#  'Seyi': 705,
#  'Shota': 706,
#  'Afghanis': 707,
#  'Talaeng': 708,
#  'earners': 709,
#  'Sedibe': 710,
#  'Saadat': 711,
#  'Rouen': 712,
#  'Virgin': 713,
#  'Gang': 714,
#  'Rotterdam': 715,
#  'Psychiatrist': 716,
#  'confuse': 717,
#  'Preventive': 718,
#  'Performing': 719,
#  'Chilean': 720,
#  'famed': 721,
#  'Morse': 722,
#  '104': 723,
#  'Speakers': 724,
#  'exclusion': 725,
#  'excluded': 726,
#  'incoming': 727,
#  'handpicked': 728,
#  '123-kilometer': 729,
#  'followed': 730,
#  'peacefully': 731,
#  'Tachileik': 732,
#  'fracture': 733,
#  'Kabal': 734,
#  'enlargement': 735,
#  'waivers': 736,
#  'churn': 737,
#  'arrest': 738,
#  'CFA': 739,
#  '3.55': 740,
#  'Hapoalim': 741,
#  'Osmani': 742,
#  '81': 743,
#  'hijackings': 744,
#  'Presutti': 745,
#  'Petter': 746,
#  'Protection': 747,
#  'handgun': 748,
#  'recessed': 749,
#  'Dayton': 750,
#  'Thompson': 751,
#  'Chirac': 752,
#  'Dawa': 753,
#  'pool': 754,
#  'forthcoming': 755,
#  'annulled': 756,
#  'Fatherland': 757,
#  'Through': 758,
#  'Didier': 759,
#  'Jaua': 760,
#  'Twenty': 761,
#  'Kye': 762,
#  'Al-Alam': 763,
#  'cross': 764,
#  '284-6': 765,
#  'barbaric': 766,
#  'community': 767,
#  'Such': 768,
#  'Neuilly': 769,
#  'Faroe': 770,
#  'Novakatka': 771,
#  'errant': 772,
#  'swore': 773,
#  'thanks': 774,
#  'CRAB': 775,
#  'Baseball': 776,
#  'Stephen': 777,
#  'Darmawan': 778,
#  'coordinate': 779,
#  'Moussaoui': 780,
#  'outreach': 781,
#  'portraying': 782,
#  'Colon': 783,
#  'Airtour': 784,
#  'planted': 785,
#  'Antigua': 786,
#  'destroyed': 787,
#  'coupled': 788,
#  '0.068263889': 789,
#  'Hunters': 790,
#  'hijacked': 791,
#  'case': 792,
#  '8.30': 793,
#  'evaluates': 794,
#  'Ashcroft': 795,
#  'toward': 796,
#  'exactly': 797,
#  'Martyrs': 798,
#  'pro-market': 799,
#  'Dobrynska': 800,
#  'Kurram': 801,
#  'Susy': 802,
#  'al-Aqidi': 803,
#  'company': 804,
#  'Services': 805,
#  'Mnangawa': 806,
#  '40-car': 807,
#  'degraded': 808,
#  'gets': 809,
#  'imposes': 810,
#  'Abderahmane': 811,
#  'shipped': 812,
#  'Maoist-inspired': 813,
#  '27-28': 814,
#  'sidewalks': 815,
#  'store': 816,
#  'Distributors': 817,
#  '0.1': 818,
#  'fleet': 819,
#  'stronghold': 820,
#  'blindfolded': 821,
#  'billionaire': 822,
#  'rebounding': 823,
#  'Fadela': 824,
#  'Mwiraria': 825,
#  'Jalil': 826,
#  'needs': 827,
#  'ethnic-Chinese': 828,
#  'stations': 829,
#  'Wong': 830,
#  'charcoal': 831,
#  'purchase': 832,
#  'exempts': 833,
#  'attempt': 834,
#  'arms': 835,
#  'orphanage': 836,
#  'hurled': 837,
#  'manipulates': 838,
#  'Sukhorenko': 839,
#  'Angola': 840,
#  'Laos': 841,
#  'delisted': 842,
#  'Spin': 843,
#  'dwelling': 844,
#  'Schalkwyk': 845,
#  'albeit': 846,
#  'donkey': 847,
#  'comprise': 848,
#  'singer': 849,
#  'onto': 850,
#  'atttacks': 851,
#  'Derg': 852,
#  'signaled': 853,
#  'Weiner': 854,
#  'handles': 855,
#  'mid-level': 856,
#  'Papillon': 857,
#  'Espiritu': 858,
#  'Films': 859,
#  'faulted': 860,
#  'revoke': 861,
#  'Kafeel': 862,
#  'vaguely': 863,
#  'technology-intensive': 864,
#  'Justice': 865,
#  'massacres': 866,
#  '75-member': 867,
#  'Charlotte': 868,
#  'destination': 869,
#  'khz': 870,
#  'hand-chosen': 871,
#  'Jamshidi': 872,
#  'Raul': 873,
#  'Donald': 874,
#  'refrain': 875,
#  'move': 876,
#  'commonly': 877,
#  'Bajramovic': 878,
#  'fundraisers': 879,
#  'Selim': 880,
#  'dismantled': 881,
#  'requires': 882,
#  'Lahoud': 883,
#  'Bernanke': 884,
#  'customized': 885,
#  'geographical': 886,
#  'Saed': 887,
#  '9-percent': 888,
#  'sterilized': 889,
#  'muscular': 890,
#  'barreling': 891,
#  'imposed': 892,
#  'Victoria': 893,
#  'Prachanda': 894,
#  'Unrest': 895,
#  'reformers': 896,
#  'al-Uthmani': 897,
#  'surroundings': 898,
#  'war-shattered': 899,
#  'U.S.-allied': 900,
#  'agony': 901,
#  'Rohrabacher': 902,
#  'Ventures': 903,
#  'following': 904,
#  'incurred': 905,
#  'Blige': 906,
#  'five-judge': 907,
#  'razor': 908,
#  'depleting': 909,
#  '30s': 910,
#  'firmest': 911,
#  'Plavia': 912,
#  'spitting': 913,
#  'resolutely': 914,
#  'Marit': 915,
#  'blockage': 916,
#  'esteem': 917,
#  'pigs': 918,
#  'Schumer': 919,
#  'unchanged': 920,
#  'jcfundrzr@aol.com': 921,
#  'Helen': 922,
#  'Philippine': 923,
#  'Khalifa': 924,
#  'Alps': 925,
#  'Allan': 926,
#  'HMS': 927,
#  'Political': 928,
#  'predictions': 929,
#  'Mongolian': 930,
#  'minimize': 931,
#  'voluntarily': 932,
#  'UN-negotiated': 933,
#  'triangle': 934,
#  'Inquiry': 935,
#  'Guards': 936,
#  'that': 937,
#  'gladly': 938,
#  'recognition': 939,
#  'billionaires': 940,
#  'jamming': 941,
#  'minorities': 942,
#  'Sufis': 943,
#  'pyramids': 944,
#  'drones': 945,
#  'anti-trust': 946,
#  'predicts': 947,
#  'Tyson': 948,
#  '90-81': 949,
#  'African-American': 950,
#  'non-farm': 951,
#  'crew': 952,
#  'Golborne': 953,
#  'approached': 954,
#  'demonstrably': 955,
#  'Indus': 956,
#  'Ruiz': 957,
#  'Liabedzka': 958,
#  'Nova': 959,
#  'Merle': 960,
#  '10-month-old': 961,
#  'someday': 962,
#  'DAY': 963,
#  'vestige': 964,
#  'looped': 965,
#  'Walt': 966,
#  '770': 967,
#  'socially-conservative': 968,
#  'Zhaoxing': 969,
#  'newly-appointed': 970,
#  'Xinjuan': 971,
#  'domestic': 972,
#  'BP': 973,
#  'separatists': 974,
#  'Coahuila': 975,
#  'Fratto': 976,
#  'loose': 977,
#  'Campaign': 978,
#  'poke': 979,
#  'wrestling': 980,
#  'mudslide': 981,
#  'grips': 982,
#  'cybersecurity': 983,
#  'hay': 984,
#  'uses': 985,
#  'Lodi': 986,
#  'bank': 987,
#  'Shebaa': 988,
#  'radiation': 989,
#  'ship': 990,
#  'pens': 991,
#  'NEW': 992,
#  'Scheuer': 993,
#  'displeased': 994,
#  'heroin': 995,
#  'Tom': 996,
#  'warning': 997,
#  'tire': 998,
#  'multi-million-selling': 999,
#  'high-income': 1000,
#  ...}

# %% [markdown]
# ### 5. Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### 6. Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### 7. Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.959, max:    0.989, cur:    0.989)
# 	validation       	 (min:    0.981, max:    0.985, cur:    0.985)
# Loss
# 	training         	 (min:    0.038, max:    0.178, cur:    0.038)
# 	validation       	 (min:    0.049, max:    0.066, cur:    0.049)
#
# Epoch 00003: val_loss improved from 0.05122 to 0.04855, saving model to model_weights.h5
# Wall time: 9min 19s

# %% [markdown]
# ### 8. Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0485 - accuracy: 0.9855 0s - loss: 0.0
# [0.04854968190193176, 0.9854878783226013]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# United         B-org	B-org
# Nations        I-org	I-org
# has            O	O
# been           O	O
# under          O	O
# fire           O	O
# for            O	O
# failing        O	O
# to             O	O
# stop           O	O
# ongoing        O	O
# ethnic         O	O
# violence       O	O
# in             O	O
# Ituri          B-geo	B-geo
# .              O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
# branch         O	O
